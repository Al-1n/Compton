# %% [markdown]
# This project uses the lmfit package. Lmfit provides curve fiting using non-linear least squares minimization
# and was developed by Matt Newville: https://github.com/newville.

# %%
#install lmfit

#uncomment the following lines to install lmfit

#from subprocess import call
# call(['pip', 'install', 'lmfit'])
# call(['pip', 'install', 'matplotlib'])
#call(['pip', 'install', 'ipympl'])

#import libraries
from numpy import sqrt, pi, exp, linspace, loadtxt
from lmfit.models import GaussianModel, MoffatModel
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np
import matplotlib.lines as mlines
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %%
#Uncomment the next line to make the graph interactive
# %matplotlib widget
#%matplotlib inline 

# Load the data
df = pd.read_csv("./Data/Ba133_vs_channel.csv", sep=" ")
df.rename(columns={"1": "Channel", "0": "Counts"}, inplace=True)

df = df[df['Channel'] <= 450]

#preview the spectrum
plt.plot('Channel', 'Counts', data = df, marker = ".")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Define the channel ranges
channel_ranges = [0, 40, 52, 85, 97, 150, 192, 230, 295, 450]

# Create labels for the ranges
labels = [f"Range {i}-{j}" for i, j in zip(channel_ranges[:-1], channel_ranges[1:])]

# Use pd.cut() to categorize the data into the specified ranges
df['Channel Range'] = pd.cut(df['Channel'], bins=channel_ranges, labels=labels, include_lowest=True)

# Create a dictionary of DataFrames, one for each channel range
channel_range_dfs = {label: group for label, group in df.groupby('Channel Range')}

# Access individual DataFrames using keys (e.g., channel_range_dfs['Range 0-40'])
channel_range_dfs['Range 40-52'].head()
# Out:
#     Channel  Counts Channel Range
# 39       41      40   Range 40-52
# 40       42      50   Range 40-52
# 41       43      52   Range 40-52
# 42       44      57   Range 40-52
# 43       45      52   Range 40-52

# %%
#use builtin NameModel, specify prefix for each:
mod1 = MoffatModel(prefix='g1_')
mod2 = MoffatModel(prefix='g2_') 
mod3 = MoffatModel(prefix='g3_')
mod4 = MoffatModel(prefix='g4_') 
mod5 = MoffatModel(prefix='g5_')

mod8 = MoffatModel(prefix='g8_')

# %%
#initialize the parameters to be optimized
pars1  = mod1.make_params(g1_amplitude=440.0, g1_center=29.6, g1_sigma=6.7, g1_beta=1)
pars2  = mod2.make_params(g2_amplitude=76.0, g2_center=48.2, g2_sigma=1.83, g2_beta=1)                         
pars3  = mod3.make_params(g3_amplitude=284.5, g3_center=69.7, g3_sigma=5.34, g3_beta=1)
pars4  = mod4.make_params(g4_amplitude=125.0, g4_center=91.5, g4_sigma=1.83, g4_beta=1)
pars5  = mod5.make_params(g5_amplitude=156.0, g5_center=104.0, g5_sigma=8.7, g5_beta=1)

pars8  = mod8.make_params(g8_amplitude=105.0, g8_center=256.0, g8_sigma=10.7, g8_beta=1)

# %%
#fit with weights=1./yerr
result1 = mod1.fit(channel_range_dfs['Range 0-40']['Counts'], pars1, x = channel_range_dfs['Range 0-40']['Channel'])
result2 = mod2.fit(channel_range_dfs['Range 40-52']['Counts'], pars2, x = channel_range_dfs['Range 40-52']['Channel'])
result3 = mod3.fit(channel_range_dfs['Range 52-85']['Counts'], pars3, x = channel_range_dfs['Range 52-85']['Channel'])
result4 = mod4.fit(channel_range_dfs['Range 85-97']['Counts'], pars4, x = channel_range_dfs['Range 85-97']['Channel'])
result5 = mod5.fit(channel_range_dfs['Range 97-150']['Counts'], pars5, x = channel_range_dfs['Range 97-150']['Channel'])

result8 = mod8.fit(channel_range_dfs['Range 230-295']['Counts'], pars8, x = channel_range_dfs['Range 230-295']['Channel'])

# %%
#print the Fit Statistics and parameters
print()
print(result1.fit_report())
print()
print(result2.fit_report())
print()
print(result3.fit_report())
print()
print(result4.fit_report())
print()
print(result5.fit_report())
print()
print(result8.fit_report())
print()
# Out:
# [[Model]]
#     Model(moffat, prefix='g1_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 39
#     # variables        = 4
#     chi-square         = 8685.16580
#     reduced chi-square = 248.147594
#     Akaike info crit   = 218.826595
#     Bayesian info crit = 225.480841
#     R-squared          = 0.98656665
# [[Variables]]
#     g1_amplitude:  416.846674 +/- 9.64067912 (2.31%) (init = 440)
#     g1_center:     29.5492146 +/- 0.07647534 (0.26%) (init = 29.6)
#     g1_sigma:      5.90070772 +/- 0.90683635 (15.37%) (init = 6.7)
#     g1_beta:       2.13788638 +/- 0.46732592 (21.86%) (init = 1)
#     g1_fwhm:       7.30308931 +/- 0.26044251 (3.57%) == '2*g1_sigma*sqrt(2**(1.0/max(1e-3, g1_beta))-1)'
#     g1_height:     416.846674 +/- 9.64067912 (2.31%) == 'g1_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g1_sigma, g1_beta)      = +0.9845
#     C(g1_amplitude, g1_sigma) = -0.5220
#     C(g1_amplitude, g1_beta)  = -0.4266
#
# [[Model]]
#     Model(moffat, prefix='g2_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1223
#     # data points      = 12
#     # variables        = 4
#     chi-square         = 288.308209
#     reduced chi-square = 36.0385261
#     Akaike info crit   = 46.1494811
#     Bayesian info crit = 48.0891077
#     R-squared          = 0.67774790
# [[Variables]]
#     g2_amplitude:  64.5019008 +/- 3.01162678 (4.67%) (init = 76)
#     g2_center:     50.7838281 +/- 4.36742376 (8.60%) (init = 48.2)
#     g2_sigma:      950.238120 +/- 13602219.9 (1431453.82%) (init = 1.83)
#     g2_beta:       3759.51113 +/- 1.0703e+08 (2846896.93%) (init = 1)
#     g2_fwhm:       25.8065238 +/- 2024.69195 (7845.66%) == '2*g2_sigma*sqrt(2**(1.0/max(1e-3, g2_beta))-1)'
#     g2_height:     64.5019008 +/- 3.01162677 (4.67%) == 'g2_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g2_sigma, g2_beta)       = +1.0000
#     C(g2_center, g2_sigma)     = +0.7224
#     C(g2_center, g2_beta)      = +0.7224
#     C(g2_amplitude, g2_center) = +0.2561
#     C(g2_amplitude, g2_beta)   = -0.1519
#     C(g2_amplitude, g2_sigma)  = -0.1519
#
# [[Model]]
#     Model(moffat, prefix='g3_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 32
#     # data points      = 33
#     # variables        = 4
#     chi-square         = 4681.95206
#     reduced chi-square = 161.446623
#     Akaike info crit   = 171.513774
#     Bayesian info crit = 177.499804
#     R-squared          = 0.96718102
# [[Variables]]
#     g3_amplitude:  266.445442 +/- 6.03645722 (2.27%) (init = 284.5)
#     g3_center:     70.4044823 +/- 0.17232785 (0.24%) (init = 69.7)
#     g3_sigma:      7.00139011 +/- 1.13642110 (16.23%) (init = 5.34)
#     g3_beta:       0.70802015 +/- 0.12423320 (17.55%) (init = 1)
#     g3_fwhm:       18.0509691 +/- 0.74959757 (4.15%) == '2*g3_sigma*sqrt(2**(1.0/max(1e-3, g3_beta))-1)'
#     g3_height:     266.445442 +/- 6.03645721 (2.27%) == 'g3_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g3_sigma, g3_beta)      = +0.9751
#     C(g3_amplitude, g3_sigma) = -0.6208
#     C(g3_amplitude, g3_beta)  = -0.4875
#
# [[Model]]
#     Model(moffat, prefix='g4_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 164
#     # data points      = 12
#     # variables        = 4
#     chi-square         = 687.196169
#     reduced chi-square = 85.8995211
#     Akaike info crit   = 56.5725577
#     Bayesian info crit = 58.5121843
#     R-squared          = 0.50726852
# [[Variables]]
#     g4_amplitude:  118.212150 +/- 6.24443723 (5.28%) (init = 125)
#     g4_center:     92.7215409 +/- 0.75534141 (0.81%) (init = 91.5)
#     g4_sigma:      2.99017399 +/- 4.65616710 (155.72%) (init = 1.83)
#     g4_beta:       0.12789906 +/- 0.20107297 (157.21%) (init = 1)
#     g4_fwhm:       89.6579726 +/- 250.021307 (278.86%) == '2*g4_sigma*sqrt(2**(1.0/max(1e-3, g4_beta))-1)'
#     g4_height:     118.212150 +/- 6.24443721 (5.28%) == 'g4_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g4_sigma, g4_beta)      = +0.9724
#     C(g4_amplitude, g4_sigma) = -0.6653
#     C(g4_amplitude, g4_beta)  = -0.5125
#     C(g4_center, g4_beta)     = -0.2377
#     C(g4_center, g4_sigma)    = -0.1810
#
# [[Model]]
#     Model(moffat, prefix='g5_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 48
#     # data points      = 53
#     # variables        = 4
#     chi-square         = 4670.18595
#     reduced chi-square = 95.3099174
#     Akaike info crit   = 245.369100
#     Bayesian info crit = 253.250267
#     R-squared          = 0.89711930
# [[Variables]]
#     g5_amplitude:  133.004071 +/- 3.97744384 (2.99%) (init = 156)
#     g5_center:     102.374869 +/- 0.98481087 (0.96%) (init = 104)
#     g5_sigma:      7.05156619 +/- 1.96982189 (27.93%) (init = 8.7)
#     g5_beta:       0.25449182 +/- 0.03957106 (15.55%) (init = 1)
#     g5_fwhm:       53.2117463 +/- 5.29254759 (9.95%) == '2*g5_sigma*sqrt(2**(1.0/max(1e-3, g5_beta))-1)'
#     g5_height:     133.004071 +/- 3.97744385 (2.99%) == 'g5_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g5_sigma, g5_beta)       = +0.9438
#     C(g5_amplitude, g5_sigma)  = -0.6176
#     C(g5_center, g5_sigma)     = -0.5815
#     C(g5_center, g5_beta)      = -0.4838
#     C(g5_amplitude, g5_beta)   = -0.4339
#     C(g5_amplitude, g5_center) = +0.1415
#
# [[Model]]
#     Model(moffat, prefix='g8_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 65
#     # variables        = 4
#     chi-square         = 3881.18092
#     reduced chi-square = 63.6259167
#     Akaike info crit   = 273.817986
#     Bayesian info crit = 282.515535
#     R-squared          = 0.85776038
# [[Variables]]
#     g8_amplitude:  84.8941031 +/- 2.79281408 (3.29%) (init = 105)
#     g8_center:     254.700528 +/- 0.55181067 (0.22%) (init = 256)
#     g8_sigma:      10.9221655 +/- 2.43882501 (22.33%) (init = 10.7)
#     g8_beta:       0.45931822 +/- 0.09195636 (20.02%) (init = 1)
#     g8_fwhm:       40.9985026 +/- 2.79982222 (6.83%) == '2*g8_sigma*sqrt(2**(1.0/max(1e-3, g8_beta))-1)'
#     g8_height:     84.8941031 +/- 2.79281407 (3.29%) == 'g8_amplitude'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(g8_sigma, g8_beta)      = +0.9561
#     C(g8_amplitude, g8_sigma) = -0.6480
#     C(g8_amplitude, g8_beta)  = -0.4616
#     C(g8_center, g8_beta)     = +0.1428
#     C(g8_center, g8_sigma)    = +0.1068

# %%
# %matplotlib widget

plt.figure(figsize=(9,6))

#plot data and models
plt.plot('Channel', 'Counts', data =  channel_range_dfs['Range 0-40'], color = '#7c8bfd', marker = ".")
plt.plot(channel_range_dfs['Range 0-40']['Channel'], result1.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 40-52'], color = '#7c8bfd', marker = ".")
plt.plot(channel_range_dfs['Range 40-52']['Channel'], result2.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 52-85'], color = '#7c8bfd', marker = ".")
plt.plot(channel_range_dfs['Range 52-85']['Channel'], result3.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 85-97'], color = '#7c8bfd', marker = ".")
plt.plot(channel_range_dfs['Range 85-97']['Channel'], result4.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 97-150'], color = '#7c8bfd', marker = ".")
plt.plot(channel_range_dfs['Range 97-150']['Channel'], result5.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 150-192'], color = '#7c8bfd', marker = ".")

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 192-230'], color = '#7c8bfd', marker = ".")

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 230-295'], color = '#7c8bfd', marker = ",")
plt.plot(channel_range_dfs['Range 230-295']['Channel'], result8.best_fit, 'r-', linewidth=2.5)

plt.plot('Channel', 'Counts', data = channel_range_dfs['Range 295-450'], color = '#7c8bfd', marker = ".")


plt.title('The (uncalibrated) decay spectrum of Ba-133', y = 1.07)

plt.ylim(7, 500) 

#uncomment the line bellow to activate the semilog scale
#plt.yscale('log')

#make annotations
plt.annotate('Cs K X-ray', xy=(33, 389), xytext=(45, 450),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc"),
            )

plt.annotate('gamma @80.9971keV', xy=(76, 238), xytext=(88, 299),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc"),
            )

plt.annotate('gamma @160.613keV', xy=(114, 114), xytext=(126, 200),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc"),
            )

plt.annotate('gamma @356.017keV', xy=(268, 80), xytext=(300, 120),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc"),
            )

# Create legend entries for the blue and red lines (data and model) and display the legend
blue_line = mlines.Line2D([], [], color='#7c8bfd', label='Data')

red_line = mlines.Line2D([], [], color='red', label='Moffat Fit', linewidth=2.5)

plt.legend([blue_line, red_line], ['Data', 'Moffat Fit'], loc='lower center', bbox_to_anchor= (0.5, 1.005), ncol=2,
            borderaxespad=0, frameon=False)


#show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---
#
# ## References
#
# ### **The images below are included as a reference for the decay scheme and gamma ray energies**

# %% [markdown]
# ![](./img/Ba_spectrum.png)
#
# https://gammaray.inl.gov/SiteAssets/catalogs/nai/pdf/ba133.pdf
#
#
# ![](./img/Ba_gamma.png)
#
# https://gammaray.inl.gov/SiteAssets/catalogs/nai/pdf/ba133.pdf
#
#
# ![](./img/Ba_energy_table.png)
#
#
# https://nucleardata.nuclear.lu.se/toi/nuclide.asp?iZA=560133
